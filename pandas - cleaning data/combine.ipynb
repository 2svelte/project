# %%
# import pandas 
import pandas as pd

# import dataset
df = pd.read_csv(r"C:\Users\Nadia\Desktop\UNI\3179\current sem\Assignment 2\datasets\not cleaned yet\disaster_cost.csv")

df.head()
# Out:
#                                                Event Begin Date   End Date  \
# 0             Western Drought and Heatwave June 2021   1/1/2021  6/30/2021
# 1  Louisiana Flooding and Central Severe Weather ...  5/15/2021  5/19/2021
# 2       Texas and Oklahoma Severe Weather April 2021  4/27/2021  4/28/2021
# 3                       Texas Hail Storms April 2021  4/12/2021  4/15/2021
# 4                  Eastern Severe Weather March 2021  3/27/2021  3/28/2021
#
#    Deaths CPI-Adjusted Estimated Cost (In Billions)  \
# 0     138                                       TBD
# 1       5                                    $1.30
# 2       0                                    $2.30
# 3       0                                    $1.20
# 4       8                                    $1.30
#
#                                              Summary
# 0  Western drought expands and intensifies across...
# 1  Torrential rainfall from thunderstorms across ...
# ...

# %%
df['CPI-Adjusted Estimated Cost (In Billions)'] = df['CPI-Adjusted Estimated Cost (In Billions)'].replace({r'\$':''}, regex = True)

# %%
df['CPI-Adjusted Estimated Cost (In Billions)'] = df['CPI-Adjusted Estimated Cost (In Billions)'].replace({r'\*':''}, regex = True)

# %%
df = df.iloc[1:]

# %%
flood = df[df['Event'].str.contains('Flood')]

# %%
df_to_csv = flood.to_csv(r"C:\Users\Nadia\Desktop\UNI\3179\current sem\Assignment 2\datasets\temp\flood.csv", index = False)

# %%
hurricane = df[df['Event'].str.contains('Hurricane')]
hurricane
# Out:
#                                  Event  Begin Date    End Date  Deaths  \
# 11         Hurricane Zeta October 2020  10/28/2020  10/29/2020       6
# 12        Hurricane Delta October 2020   10/9/2020  10/11/2020       5
# 13      Hurricane Sally September 2020   9/15/2020   9/17/2020       5
# 14         Hurricane Laura August 2020   8/27/2020   8/28/2020      42
# 16        Hurricane Isaias August 2020    8/3/2020    8/4/2020      16
# 17           Hurricane Hanna July 2020   7/25/2020   7/26/2020       0
# 33     Hurricane Dorian September 2019   8/28/2019    9/6/2019      10
# 46      Hurricane Michael October 2018  10/10/2018  10/11/2018      49
# 47   Hurricane Florence September 2018   9/13/2018   9/16/2018      53
# 60      Hurricane Maria September 2017   9/19/2017   9/21/2017    2981
# 61       Hurricane Irma September 2017    9/6/2017   9/12/2017      97
# 62        Hurricane Harvey August 2017   8/25/2017   8/31/2017      89
# ...

# %%
df_to_csv = hurricane.to_csv(r"C:\Users\Nadia\Desktop\UNI\3179\current sem\Assignment 2\datasets\temp\hurricane.csv", index = False)

# %%
storm = df[df['Event'].str.contains('torm')]
storm
# Out:
#                                                  Event  Begin Date  \
# 3                         Texas Hail Storms April 2021   4/12/2021
# 6    Northwest, Central, Eastern Winter Storm and C...   2/10/2021
# 8    Western Wildfires - California, Oregon, Washin...    8/1/2020
# 10                    Tropical Storm Eta November 2020   11/8/2020
# 19                    South Texas Hail Storms May 2020   5/27/2020
# 25   North Central and Ohio Valley Hail Storms and ...    4/7/2020
# 29   Southeast Tornadoes and Northern Storms and Fl...   1/10/2020
# 32                Tropical Storm Imelda September 2019   9/17/2019
# 35                      Colorado Hail Storms July 2019    7/4/2019
# 42                         Texas Hail Storm March 2019   3/22/2019
# 44   Western Wildfires, California Firestorm Summer...    6/1/2018
# 48          Rockies and Plains Hail Storms August 2018    8/6/2018
# 50                       Colorado Hail Storm June 2018   6/18/2018
# ...

# %%
df_to_csv = storm.to_csv(r"C:\Users\Nadia\Desktop\UNI\3179\current sem\Assignment 2\datasets\temp\storm.csv", index = False)

# %%
wildfire = df[df['Event'].str.contains('ildfire')]
wildfire
# Out:
#                                                  Event Begin Date    End Date  \
# 8    Western Wildfires - California, Oregon, Washin...   8/1/2020  12/30/2020
# 30    California and Alaska Wildfires Summer-Fall 2019   6/1/2019  11/30/2019
# 44   Western Wildfires, California Firestorm Summer...   6/1/2018  12/31/2018
# 58   Western Wildfires, California Firestorm Summer...   6/1/2017  12/31/2017
# 74       Western/ Southeast Wildfires Summer-Fall 2016   6/1/2016  12/31/2016
# 91      Western and Alaskan Wildfires Summer-Fall 2015   6/1/2015  11/30/2015
# 118                 Western Wildfires Summer-Fall 2012   6/1/2012  11/30/2012
# 128  Texas, New Mexico, Arizona Wildfires Summer-Fa...   6/1/2011  11/30/2011
# 151                 Western Wildfires Summer-Fall 2009   6/1/2009  11/30/2009
# 158                           U.S. Wildfires Fall 2008   9/1/2008  11/30/2008
# 170                      Western Wildfires Summer 2007   6/1/2007   8/31/2007
# ...

# %%
df_to_csv = wildfire.to_csv(r"C:\Users\Nadia\Desktop\UNI\3179\current sem\Assignment 2\datasets\temp\wildfire", index = False)

# %%
tornado = df[df['Event'].str.contains('ornado')]
tornado
# Out:
#                                                  Event  Begin Date  \
# 5    Southeast Tornadoes and Severe Weather March 2021   3/24/2021
# 24   Southeast and Eastern Tornado Outbreak April 2020   4/12/2020
# 27   Tennessee Tornadoes and Southeast Severe Weath...    3/2/2020
# 29   Southeast Tornadoes and Northern Storms and Fl...   1/10/2020
# 31   Texas Tornadoes and Central Severe Weather Oct...  10/20/2019
# 37   Rockies, Central and Northeast Tornadoes and S...   5/26/2019
# 40   Southern and Eastern Tornadoes and Severe Weat...   4/13/2019
# 49   Central and Eastern Tornadoes and Severe Weath...   7/19/2018
# 54   Southern and Eastern Tornadoes and Severe Weat...   4/13/2018
# 55   Southeastern Tornadoes and Severe Weather Marc...   3/18/2018
# 70                 Midwest Tornado Outbreak March 2017    3/6/2017
# 71      Central/ Southeast Tornado Outbreak March 2017   2/28/2017
# 73   Southern Tornado Outbreak and Western Storms J...   1/20/2017
# ...

# %%
df_to_csv = tornado.to_csv(r"C:\Users\Nadia\Desktop\UNI\3179\current sem\Assignment 2\datasets\temp\tornado.csv", index = False)
