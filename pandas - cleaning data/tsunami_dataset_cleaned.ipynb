# %%
# import pandas 
import pandas as pd

# import dataset
df = pd.read_csv(r"C:\Users\Nadia\Desktop\UNI\3179\current sem\Assignment 2\Natural Disasters Datasets\not cleaned yet\tsunami_dataset.csv")

df.head()
# Out:
#    YEAR  MONTH  LATITUDE  LONGITUDE                        LOCATION_NAME  \
# 0  -330    NaN     40.00     25.000  E. SPORADES ISLANDS, AEGEAN ISLANDS
# 1  1764    2.0     51.45     -2.583                     BRISTOL, ENGLAND
# 2   859    NaN     36.08     36.250                            SAMANDAGI
# 3  1580    1.0     40.00    128.000                           YELLOW SEA
# 4 -1300    NaN     39.96     26.240                 IONIAN COASTS, TROAD
#
#        COUNTRY         EVENT_VALIDITY  EQ_MAGNITUDE  EQ_DEPTH  TS_INTENSITY  \
# 0       GREECE  Very Doubtful Tsunami           7.0       NaN           NaN
# 1           UK  Very Doubtful Tsunami           NaN       NaN           NaN
# 2       TURKEY   Questionable Tsunami           NaN       NaN           3.0
# 3  NORTH KOREA  Very Doubtful Tsunami           NaN       NaN           1.0
# 4       TURKEY   Questionable Tsunami           6.0       NaN           5.0
#
#   DAMAGE_TOTAL_DESCRIPTION DEATHS_TOTAL_DESCRIPTION
# ...

# %%
# check if there is any null values in columns
df.isnull().sum()
# Out:
# YEAR                           0
# MONTH                        104
# LATITUDE                       0
# LONGITUDE                      0
# LOCATION_NAME                  9
# COUNTRY                        0
# EVENT_VALIDITY                 0
# EQ_MAGNITUDE                 785
# EQ_DEPTH                    1352
# TS_INTENSITY                1158
# DAMAGE_TOTAL_DESCRIPTION    1204
# DEATHS_TOTAL_DESCRIPTION    1585
# dtype: int64

# %%
df = df.loc[(df['EVENT_VALIDITY'] == "Probable Tsunami") | (df['EVENT_VALIDITY'] == "Definite Tsunami")]
df = df.loc[ (df['YEAR'] > 0) & (df['YEAR'] >=1900)]
df
# Out:
#       YEAR  MONTH  LATITUDE  LONGITUDE                        LOCATION_NAME  \
# 587   1907    9.0    59.500   -135.500                          SKAGWAY, AK
# 591   1922    1.0    -7.111    143.530                         BISMARCK SEA
# 592   1901    3.0    36.000   -120.500          MONTEREY BAY, N. CALIFORNIA
# 608   1915    8.0    38.500     20.700                           IONIAN SEA
# 611   1901    6.0    39.000    143.000                         IWATE, JAPAN
# ...    ...    ...       ...        ...                                  ...
# 2252  2020    5.0    34.205     25.712                                CRETE
# 2254  2020    7.0    55.030   -158.522                 SHUMAGIN ISLANDS, AK
# 2255  2020    6.0   -33.294   -177.838  S OF RAOUL ISLAND, KERMADEC ISLANDS
# 2256  2013    4.0    18.081   -102.182                               MEXICO
# 2258  2020    6.0    16.029    -95.901               OFF OF COAST OF OAXACA
#
# ...

# %%
df = df[df['EQ_MAGNITUDE'].notna()]
df
# Out:
#       YEAR  MONTH  LATITUDE  LONGITUDE                        LOCATION_NAME  \
# 587   1907    9.0    59.500   -135.500                          SKAGWAY, AK
# 591   1922    1.0    -7.111    143.530                         BISMARCK SEA
# 592   1901    3.0    36.000   -120.500          MONTEREY BAY, N. CALIFORNIA
# 608   1915    8.0    38.500     20.700                           IONIAN SEA
# 611   1901    6.0    39.000    143.000                         IWATE, JAPAN
# ...    ...    ...       ...        ...                                  ...
# 2252  2020    5.0    34.205     25.712                                CRETE
# 2254  2020    7.0    55.030   -158.522                 SHUMAGIN ISLANDS, AK
# 2255  2020    6.0   -33.294   -177.838  S OF RAOUL ISLAND, KERMADEC ISLANDS
# 2256  2013    4.0    18.081   -102.182                               MEXICO
# 2258  2020    6.0    16.029    -95.901               OFF OF COAST OF OAXACA
#
# ...

# %%
df_to_csv = df.to_csv(r"C:\Users\Nadia\Desktop\UNI\3179\current sem\Assignment 2\Natural Disasters Datasets\cleaned\tsunami_dataset_cleaned.csv", index = False)
