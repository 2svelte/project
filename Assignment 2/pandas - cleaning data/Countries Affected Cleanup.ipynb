# %%
# import pandas 
import pandas as pd

# import dataset
df = pd.read_csv(r"C:\Users\Nadia\Desktop\UNI\3179\current sem\Assignment 2\datasets\not cleaned yet\1900_2021_DISASTERS - emdat data.csv")

df.head()
# Out:
#    Year      Disaster Type Disaster Subtype     Country Continent  \
# 0  1900            Drought          Drought  Cabo Verde    Africa
# 1  1900            Drought          Drought       India      Asia
# 2  1902         Earthquake  Ground movement   Guatemala  Americas
# 3  1902  Volcanic activity         Ash fall   Guatemala  Americas
# 4  1902  Volcanic activity         Ash fall   Guatemala  Americas
#
#    Magnitude Value Magnitude Scale Latitude Longitude  Start Month  End Year  \
# 0              NaN             Km2      NaN       NaN          NaN      1900
# 1              NaN             Km2      NaN       NaN          NaN      1900
# 2              8.0         Richter       14       -91          4.0      1902
# 3              NaN             NaN      NaN       NaN          4.0      1902
# 4              NaN             NaN      NaN       NaN         10.0      1902
#
#    End Month  Total Deaths  No Injured  Total Affected  No Homeless  \
# ...

# %%
# check if there is any null values in columns
df.isnull().sum()
# Out:
# Year                              0
# Disaster Type                     0
# Disaster Subtype               3110
# Country                           0
# Continent                         0
# Magnitude Value               11180
# Magnitude Scale                1190
# Latitude                      13397
# Longitude                     13394
# Start Month                     387
# End Year                          0
# End Month                       708
# Total Deaths                   4713
# No Injured                    12231
# Total Affected                    0
# No Homeless                   13696
# Insured Damages ('000 US$)    15030
# Total Damages ('000 US$)      10881
# dtype: int64

# %%
# Export just year and countries affected
df = df[['Year', 'Country', 'Disaster Type', 'Total Deaths']]
df
# Out:
#        Year                                 Country      Disaster Type  \
# 0      1900                              Cabo Verde            Drought
# 1      1900                                   India            Drought
# 2      1902                               Guatemala         Earthquake
# 3      1902                               Guatemala  Volcanic activity
# 4      1902                               Guatemala  Volcanic activity
# ...     ...                                     ...                ...
# 16121  2021                                   Yemen              Flood
# 16122  2021                            South Africa              Flood
# 16123  2021  Congo (the Democratic Republic of the)           Epidemic
# 16124  2021                                  Serbia              Flood
# 16125  2021                             South Sudan              Flood
#
#        Total Deaths
# 0           11000.0
# 1         1250000.0
# 2            2000.0
# 3            1000.0
# ...

# %%
df = df[df['Total Deaths'].notna()]
df
# Out:
#        Year                                 Country      Disaster Type  \
# 0      1900                              Cabo Verde            Drought
# 1      1900                                   India            Drought
# 2      1902                               Guatemala         Earthquake
# 3      1902                               Guatemala  Volcanic activity
# 4      1902                               Guatemala  Volcanic activity
# ...     ...                                     ...                ...
# 16120  2021                                   Yemen              Flood
# 16121  2021                                   Yemen              Flood
# 16122  2021                            South Africa              Flood
# 16123  2021  Congo (the Democratic Republic of the)           Epidemic
# 16125  2021                             South Sudan              Flood
#
#        Total Deaths
# 0           11000.0
# 1         1250000.0
# 2            2000.0
# 3            1000.0
# ...

# %%
df.columns = ['Year', 'Country', 'Disaster', 'Deaths']
df
# Out:
#        Year                                 Country           Disaster  \
# 0      1900                              Cabo Verde            Drought
# 1      1900                                   India            Drought
# 2      1902                               Guatemala         Earthquake
# 3      1902                               Guatemala  Volcanic activity
# 4      1902                               Guatemala  Volcanic activity
# ...     ...                                     ...                ...
# 16120  2021                                   Yemen              Flood
# 16121  2021                                   Yemen              Flood
# 16122  2021                            South Africa              Flood
# 16123  2021  Congo (the Democratic Republic of the)           Epidemic
# 16125  2021                             South Sudan              Flood
#
#           Deaths
# 0        11000.0
# 1      1250000.0
# 2         2000.0
# 3         1000.0
# 4         6000.0
# ...

# %%
sel_disaster = ['Drought', 'Earthquake', 'Epidemic', 'Flood', 'Storm', 'Volcanic activity', 'Wildfire']

df = df[df['Disaster'].isin(sel_disaster)]
df
# Out:
#        Year                                 Country           Disaster  \
# 0      1900                              Cabo Verde            Drought
# 1      1900                                   India            Drought
# 2      1902                               Guatemala         Earthquake
# 3      1902                               Guatemala  Volcanic activity
# 4      1902                               Guatemala  Volcanic activity
# ...     ...                                     ...                ...
# 16120  2021                                   Yemen              Flood
# 16121  2021                                   Yemen              Flood
# 16122  2021                            South Africa              Flood
# 16123  2021  Congo (the Democratic Republic of the)           Epidemic
# 16125  2021                             South Sudan              Flood
#
#           Deaths
# 0        11000.0
# 1      1250000.0
# 2         2000.0
# 3         1000.0
# 4         6000.0
# ...

# %%
df.loc[df["Deaths"]].map('{:,.0f}'.format)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-53ff5d27f7cb> in <module>
# ----> 1 df.loc[df["Deaths"]].map('{:,.0f}'.format)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1111                     raise ValueError("Cannot index with multidimensional key")
#    1112
# -> 1113                 return self._getitem_iterable(key, axis=axis)
#    1114
#    1115             # nested tuple slicing
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1051
# ...

# %%
df_to_csv = df.to_csv(r"C:\Users\Nadia\Desktop\UNI\3179\current sem\Assignment 2\Natural Disasters Datasets\cleaned\natural_disasters_death(cleaned).csv", index = False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-c5e75e712aad> in <module>
# ----> 1 df_to_csv = df.to_csv(r"C:\Users\Nadia\Desktop\UNI\3179\current sem\Assignment 2\Natural Disasters Datasets\cleaned\natural_disasters_death(cleaned).csv", index = False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ...
